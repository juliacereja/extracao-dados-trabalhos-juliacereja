# %% [markdown]
# # Exercício 4 — Sua própria coleta com Zeeschuimer
#
# Este exercício repete o fluxo da aula (instalar → coletar → exportar → explorar → nuvens de palavras → downloads), com um recorte escolhido por você, e aprofunda a parte de métricas, que na aula ficou só no superficial.
#
# Na aula você viu a leitura do CSV de duas formas, com `csv` e com `pandas`. Aqui em diante, use sempre o `pandas`: ele deixa cálculos de métrica (média, máximo, agrupamento por autor) bem mais diretos do que fazer isso na mão com listas.
#
# Antes de TUDO, copie a pasta `exercicios/` para dentro da sua pasta de entregas (`extracao-dados-trabalhos-SeuNome`, lembrando que é o SEU nome, não o meu 🙃), dentro de uma pasta `04-coleta-redes` em `projetos/`.

# %% [markdown]
# ## Preparação do ambiente
#
# Como este notebook vai morar numa pasta própria (dentro da sua pasta de entregas, fora do material do curso), crie o ambiente e instale as dependências de novo, dentro da pasta `exercicios/` copiada:
#
# ```cmd
# uv venv .venv
# uv pip install -r requirements.txt
# ```
#
# Se o `uv` não funcionar, use `pip install -r requirements.txt` com o ambiente já ativado.

# %% [markdown]
# ## Parte 0 — Escolha do recorte
#
# Escolha, dentro do que foi combinado em aula (plataforma e tipo de recorte permitidos), um alvo específico para a sua coleta: uma hashtag, um perfil público ou uma busca. Registre aqui antes de coletar:
#
# **Plataforma:**
#
# TikTok
#
# **Recorte escolhido (hashtag, perfil ou busca):**
#
# #amigurumi (inspirado no Snoopy do tio pepe)
#
# **ATENÇÃO:** o recorte precisa ser público e caber no que foi combinado em aula. Nada de perfis privados, conteúdo de menores de idade ou qualquer coisa fora do escopo demonstrativo.

# %% [markdown]
# ## Parte 1 — Coleta e exportação
#
# Com o Firefox e o Zeeschuimer já instalados (seções 3 e 4 da aula), repita o fluxo:
#
# 1. Abra o recorte escolhido na Parte 0 e role o feed normalmente por alguns minutos.
# 2. Confira no ícone do Zeeschuimer que os itens estão sendo capturados.
# 3. Exporte a coleta (painel da extensão → opção de exportação). O arquivo vem em CSV, separado por `;`.
# 4. Renomeie o arquivo para `exportacao.csv` e salve dentro de `exercicios/dados/` (crie a pasta se não existir).
#
# **OBS:** não precisa de uma coleta grande. Poucos minutos de rolagem, com algumas centenas de itens capturados, já são suficientes para o exercício. Máximo de 500.

# %% [markdown]
# ## Parte 2 — Quais são as variáveis?
#
# Antes de sair usando o arquivo, explore o cabeçalho: rode a célula abaixo e leia com calma as colunas e os valores do primeiro item.

# %%
import pandas as pd

df = pd.read_csv("dados/exportacao.csv", sep=";")

print(f"Linhas coletadas: {len(df)}")
df.iloc[0]
# Out:
# Linhas coletadas: 84
# collected_from_url        https://www.tiktok.com/search?q=#amigurumi&t=1...
# id                                                      7379335242047409413
# thread_id                                               7379335242047409413
# author                                                            artenoape
# author_full                                                    Mayara Prado
# author_followers                                                      40700
# author_likes                                                            503
# author_videos                                                            55
# author_avatar             https://p16-common-sign.tiktokcdn.com/tos-alis...
# body                      Resultado do meu Shrek em amigurumi 🍺💚✨ Lançam...
# stickers                                                                NaN
# timestamp                                               2024-06-11 19:49:39
# unix_timestamp                                                   1718135379
# is_duet                                                                  no
# is_ad                                                                    no
# is_paid_partnership                                                      no
# is_sensitive                                                             no
# is_photosensitive                                                        no
# music_name                                             Accidentally in Love
# music_id                                                6705230820174564102
# music_url                                                               NaN
# music_thumbnail           https://p16-sign-sg.tiktokcdn.com/tos-alisg-v-...
# music_author                                              Countdown Singers
# video_url                 https://webapp-sg.tiktok.com/aa0c8aafd0468248b...
# tiktok_url                https://www.tiktok.com/@artenoape/video/737933...
# thumbnail_url             https://p19-common-sign.tiktokcdn.com/tos-mali...
# likes                                                                785100
# comments                                                               1651
# shares                                                                92000
# plays                                                               8800000
# hashtags                  shrek,shrekamigurumi,croche,amigurumi,crochet,...
# challenges                shrek,shrekamigurumi,croche,amigurumi,crochet,...
# diversification_labels                                                  NaN
# location_created                                                        NaN
# effects                                                                 NaN
# warning                                                                 NaN
# Name: 0, dtype: object

# %% [markdown]
# Escolha cinco colunas do seu arquivo e descreva, com suas palavras, o que cada uma representa (use a tabela da Aula 4 como referência para as colunas em comum, mas repare que a sua plataforma pode ter colunas diferentes):
#
# **Coluna 1:**
#
# author_followers: é a quantidade de seguidores que o autor do vídeo tem.
#
# **Coluna 2:**
#
# body: a legenda do vídeo, normalmente sugere o conteúdo ou nicho do vídeo.
#
# **Coluna 3:**
#
# music_name: nome da música usada no vídeo.
#
# **Coluna 4:**
#
# music_author: autor da música usada.
#
# **Coluna 5:**
#
# timestamp: data e hora exata em que o vídeo foi publicado.

# %% [markdown]
# ## Parte 3 — Nuvens de palavras
#
# Repita as duas nuvens da aula: uma para o texto dos posts, outra para as hashtags. Ajuste o nome da coluna de texto se a sua plataforma usar um nome diferente de `body`.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

texto_completo = " ".join(df["body"].dropna())

nuvem = WordCloud(width=800, height=400, background_color="white").generate(texto_completo)

plt.figure(figsize=(10, 5))
plt.imshow(nuvem)
plt.axis("off")
plt.show()

# %%
hashtags_completo = " ".join(df["hashtags"].dropna().str.replace(",", " "))

nuvem_hashtags = WordCloud(width=800, height=400, background_color="white").generate(hashtags_completo)

plt.figure(figsize=(10, 5))
plt.imshow(nuvem_hashtags)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Parte 4 — Baixando thumbnails e vídeos
#
# Repita os downloads da aula. Ajuste os nomes de coluna se necessário (algumas plataformas não têm `video_url`, só imagem).

# %%
import urllib.request
from pathlib import Path

pasta_thumbnails = Path("dados/thumbnails")
pasta_thumbnails.mkdir(parents=True, exist_ok=True)

primeiras_linhas = df.head(20)

for linha in primeiras_linhas.itertuples():
    if pd.notna(linha.thumbnail_url):
        destino = pasta_thumbnails / f"{linha.id}.jpg"
        urllib.request.urlretrieve(linha.thumbnail_url, destino)

print(f"Thumbnails salvas em {pasta_thumbnails}")
# Out:
# Thumbnails salvas em dados/thumbnails

# %%
pasta_videos = Path("dados/videos")
pasta_videos.mkdir(parents=True, exist_ok=True)

primeiras_linhas = df.head(5)

for linha in primeiras_linhas.itertuples():
    if pd.notna(linha.video_url):
        destino = pasta_videos / f"{linha.id}.mp4"
        urllib.request.urlretrieve(linha.video_url, destino)

print(f"Vídeos salvos em {pasta_videos}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       5
#       6 for linha in primeiras_linhas.itertuples():
#       7     if pd.notna(linha.video_url):
#       8         destino = pasta_videos / f"{linha.id}.mp4"
# ----> 9         urllib.request.urlretrieve(linha.video_url, destino)
#      10
#      11 print(f"Vídeos salvos em {pasta_videos}")
#
# File ~/.local/share/uv/python/cpython-3.14.3-macos-x86_64-none/lib/python3.14/urllib/request.py:212, in urlretrieve(url, filename, reporthook, data)
#     195 """
#     196 Retrieve a URL into a temporary location on disk.
#     197
#    (...)    208 data file as well as the resulting HTTPMessage object.
#     209 """
#     210 url_type, path = _splittype(url)
# --> 212 with contextlib.closing(urlopen(url, data)) as fp:
#     213     headers = fp.info()
#     215     # Just return the local path and the "headers" for file://
#     216     # URLs. No sense in performing a copy unless requested.
#
# File ~/.local/share/uv/python/cpython-3.14.3-macos-x86_64-none/lib/python3.14/urllib/request.py:187, in urlopen(url, data, timeout, context)
#     185 else:
#     186     opener = _opener
# --> 187 return opener.open(url, data, timeout)
#
# File ~/.local/share/uv/python/cpython-3.14.3-macos-x86_64-none/lib/python3.14/urllib/request.py:493, in OpenerDirector.open(self, fullurl, data, timeout)
#     491 for processor in self.process_response.get(protocol, []):
#     492     meth = getattr(processor, meth_name)
# --> 493     response = meth(req, response)
#     495 return response
#
# File ~/.local/share/uv/python/cpython-3.14.3-macos-x86_64-none/lib/python3.14/urllib/request.py:602, in HTTPErrorProcessor.http_response(self, request, response)
#     599 # According to RFC 2616, "2xx" code indicates that the client's
#     600 # request was successfully received, understood, and accepted.
#     601 if not (200 <= code < 300):
# --> 602     response = self.parent.error(
#     603         'http', request, response, code, msg, hdrs)
#     605 return response
#
# File ~/.local/share/uv/python/cpython-3.14.3-macos-x86_64-none/lib/python3.14/urllib/request.py:531, in OpenerDirector.error(self, proto, *args)
#     529 if http_err:
#     530     args = (dict, 'default', 'http_error_default') + orig_args
# --> 531     return self._call_chain(*args)
#
# File ~/.local/share/uv/python/cpython-3.14.3-macos-x86_64-none/lib/python3.14/urllib/request.py:464, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     462 for handler in handlers:
#     463     func = getattr(handler, meth_name)
# --> 464     result = func(*args)
#     465     if result is not None:
#     466         return result
#
# File ~/.local/share/uv/python/cpython-3.14.3-macos-x86_64-none/lib/python3.14/urllib/request.py:611, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     610 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 611     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# ## Parte 5 — Métricas, com mais profundidade
#
# Na aula, as métricas ficaram só no superficial (vídeo mais curtido, média geral, autor mais frequente). Aqui a ideia é ir um pouco além, sempre com `pandas`: colunas, `.mean()`, `.max()`, `.groupby()`.

# %% [markdown]
# ### 5.1 — Estatísticas de cada métrica de engajamento
#
# Para `likes`, `comments`, `shares` e `plays`, calcule o mínimo, o máximo e a média. Complete o código: falta imprimir as estatísticas de `comments` e `shares`, do mesmo jeito que `likes` e `plays` já estão prontos.

# %%
print(f"Curtidas: mínimo {df['likes'].min()}, máximo {df['likes'].max()}, média {df['likes'].mean():.1f}")
print(f"Visualizações: mínimo {df['plays'].min()}, máximo {df['plays'].max()}, média {df['plays'].mean():.1f}")
print(f"Comentários: mínimo {df['comments'].min()}, máximo {df['comments'].max()}, média {df['comments'].mean():.1f}")
print(f"Compartilhamentos: mínimo {df['shares'].min()}, máximo {df['shares'].max()}, média {df['shares'].mean():.1f}")
# Out:
# Curtidas: mínimo 131, máximo 1500000, média 75427.5
# Visualizações: mínimo 2189, máximo 11200000, média 943628.8
# Comentários: mínimo 4, máximo 4974, média 481.7
# Compartilhamentos: mínimo 6, máximo 92000, média 6313.3

# %% [markdown]
# ### 5.2 — Taxa de engajamento por vídeo
#
# Curtidas em número absoluto favorecem quem tem mais visualizações. Uma forma de comparar vídeos de forma mais justa é calcular uma taxa: `(curtidas + comentários + compartilhamentos) / visualizações`. Complete a linha marcada, criando essa conta como uma nova coluna do `df`.

# %%
df_com_visualizacoes = df[df["plays"] > 0].copy()

# Calcule a taxa de engajamento para cada linha: (likes + comments + shares) / plays
# Guarde o resultado numa nova coluna, assim: df_com_visualizacoes["taxa_engajamento"] = ...

# Cálculo da taxa de engajamento
df_com_visualizacoes["taxa_engajamento"] = (
    df_com_visualizacoes["likes"]
    + df_com_visualizacoes["comments"]
    + df_com_visualizacoes["shares"]
) / df_com_visualizacoes["plays"]

print(df_com_visualizacoes)

# Depois de completar a linha acima, descomente as duas linhas abaixo:
media_engajamento = df_com_visualizacoes["taxa_engajamento"].mean()
print(f"Taxa média de engajamento: {media_engajamento:.2%}")
# Out:
#                                    collected_from_url                   id  \
# 0   https://www.tiktok.com/search?q=#amigurumi&t=1...  7379335242047409413
# 1   https://www.tiktok.com/search?q=#amigurumi&t=1...  7600013611032907015
# 2   https://www.tiktok.com/search?q=#amigurumi&t=1...  7577445719968075028
# 3   https://www.tiktok.com/search?q=#amigurumi&t=1...  7635991327582260498
# 4   https://www.tiktok.com/search?q=#amigurumi&t=1...  7441627777515687224
# ..                                                ...                  ...
# 79  https://www.tiktok.com/search?q=#amigurumi&t=1...  7411506202825313568
# 80  https://www.tiktok.com/search?q=#amigurumi&t=1...  7529016258356956421
# 81  https://www.tiktok.com/search?q=#amigurumi&t=1...  7657886293623360786
# 82  https://www.tiktok.com/search?q=#amigurumi&t=1...  7662487368582171924
# 83  https://www.tiktok.com/search?q=#amigurumi&t=1...  7338963666819190059
#
#               thread_id                  author                  author_full  \
# 0   7379335242047409413               artenoape                 Mayara Prado
# 1   7600013611032907015          useheracrochet                       Hera 🧶
# 2   7577445719968075028               juli20165             Juliene de Jesus
# 3   7635991327582260498         joiceribeiro079                Joice Ribeiro
# 4   7441627777515687224  delicadeza_pontoaponto     Delicadeza Ponto a Ponto
# ..                  ...                     ...                          ...
# 79  7411506202825313568          apinchofcotton               apinchofcotton
# 80  7529016258356956421         crochet.enlinea  Crochet y Amigurumi | CURSO
# 81  7657886293623360786      mimiloops_handmade          Mimiloops__handmade
# 82  7662487368582171924           daiaboettcher             Daiane Boettcher
# 83  7338963666819190059     mushroomsandmeadows          mushroomsANDmeadows
#
#     author_followers  author_likes  author_videos  \
# 0              40700           503             55
# 1               1055           122             23
# 2              48700          7898            114
# 3               1736          5027            143
# 4              50400           586            310
# ..               ...           ...            ...
# 79              1879            25             20
# 80             25100           261            257
# 81             20000          3302            455
# 82              2029           649            262
# 83             13800           298             57
#
#                                         author_avatar  \
# 0   https://p16-common-sign.tiktokcdn.com/tos-alis...
# 1   https://p16-common-sign.tiktokcdn.com/tos-alis...
# 2   https://p16-common-sign.tiktokcdn.com/tos-mali...
# 3   https://p16-common-sign.tiktokcdn.com/tos-alis...
# 4   https://p16-common-sign.tiktokcdn.com/tos-mali...
# ..                                                ...
# 79  https://p16-common-sign.tiktokcdn.com/tos-usea...
# 80  https://p16-common-sign.tiktokcdn.com/tos-mali...
# 81  https://p16-common-sign.tiktokcdn.com/tos-mali...
# 82  https://p16-common-sign.tiktokcdn.com/tos-alis...
# 83  https://p16-common-sign.tiktokcdn.com/tos-mali...
#
#                                                  body  ... comments shares  \
# 0   Resultado do meu Shrek em amigurumi 🍺💚✨ Lançam...  ...     1651  92000
# 1   💚🩷 #chaveiros #amigurumi #handmade #croche #cr...  ...       79     92
# 2   bebê amigurumi negra,toda confeccionada no cro...  ...     4317  11900
# 3   Acho que exagerei 🥹 maior capivara de amigurum...  ...      186    248
# 4   apaixonada pela ovelhinha 🥹🥹🥹 #ovelha #amiguru...  ...      144    331
# ..                                                ...  ...      ...    ...
# 79  Just a little, crochet banana who's showing-of...  ...      229   5893
# 80  ✨ El conejo perfecto que lo cambió todo… y cóm...  ...       81    660
# 81  #crochettutorial #amigurumitutorial #tutorial ...  ...      166   1349
# 82  ​O segredo para começar no amigurumi sem passa...  ...        4      6
# 83  💕👶Bundle Babies👶💕 (Sorry for the bad lighting ...  ...      417   3409
#
#       plays                                           hashtags  \
# 0   8800000  shrek,shrekamigurumi,croche,amigurumi,crochet,...
# 1     64600        chaveiros,amigurumi,handmade,croche,crochet
# 2   2100000                                                NaN
# 3     57100  fiochenille,capivara,amigurumis,croche,jaguariuna
# 4     99600        ovelha,amigurumi,croch,crochet,fy,fyp,viral
# ..      ...                                                ...
# 79   265800  crocheting,crochet,amigurumi,szydełkowanie,han...
# 80   213700  crochet,amigurumi,amigurumis,ganchillo,tejido,...
# 81  4600000  crochettutorial,amigurumitutorial,tutorial,cro...
# 82     8284  fioamigurumi,crocheteira,linhaparaamigurumi,li...
# 83   484300  crochetbabydoll,crochetersoftiktok,babydoll,cr...
#
#                                            challenges diversification_labels  \
# 0   shrek,shrekamigurumi,croche,amigurumi,crochet,...                    NaN
# 1         chaveiros,amigurumi,handmade,croche,crochet                    NaN
# 2                                                 NaN                    NaN
# 3   fiochenille,capivara,amigurumis,croche,jaguariuna                    NaN
# 4         ovelha,amigurumi,croch,crochet,fy,fyp,viral                    NaN
# ..                                                ...                    ...
# 79  crocheting,crochet,amigurumi,szydełkowanie,han...                    NaN
# 80  crochet,amigurumi,amigurumis,ganchillo,tejido,...                    NaN
# 81  crochettutorial,amigurumitutorial,tutorial,cro...                    NaN
# 82  fioamigurumi,crocheteira,linhaparaamigurumi,li...                    NaN
# 83  crochetbabydoll,crochetersoftiktok,babydoll,cr...                    NaN
#
#    location_created                            effects warning  \
# 0               NaN                                NaN     NaN
# 1               NaN                                NaN     NaN
# 2               NaN                                NaN     NaN
# 3               NaN                                NaN     NaN
# 4               NaN                                NaN     NaN
# ..              ...                                ...     ...
# 79              NaN  Kyomi,angelic makeup,High Quality     NaN
# 80              NaN  angelic makeup,High Quality,Kyomi     NaN
# 81              NaN                                NaN     NaN
# 82              NaN                                NaN     NaN
# 83              NaN  High Quality,Kyomi,angelic makeup     NaN
#
#     taxa_engajamento
# 0           0.099858
# 1           0.036409
# 2           0.065246
# 3           0.065832
# 4           0.070803
# ..               ...
# 79          0.037073
# 80          0.020749
# 81          0.007742
# 82          0.017021
# 83          0.034743
#
# [84 rows x 37 columns]
# Taxa média de engajamento: 7.55%

# %% [markdown]
# **O que observar:** vídeos com poucas visualizações podem ter taxa de engajamento alta mesmo com poucas curtidas em número absoluto. Compare o vídeo mais curtido em número absoluto (que você calculou na aula) com o vídeo de maior taxa de engajamento, eles costumam ser diferentes.

# %% [markdown]
# ### 5.3 — Curtidas médias por autor, em gráfico
#
# Agrupe as linhas por autor com `df.groupby("author")`, calcule a média de curtidas de cada um, e monte um gráfico de barras com os 10 autores que mais apareceram na sua coleta.

# %%
top_autores = df["author"].value_counts().head(10)

media_por_autor = df.groupby("author")["likes"].mean()
medias_dos_top_autores = media_por_autor[top_autores.index]

plt.figure(figsize=(10, 5))
medias_dos_top_autores.plot(kind="bar")
plt.xticks(rotation=45, ha="right")
plt.ylabel("Média de curtidas")
plt.title("Curtidas médias dos 10 autores que mais apareceram na coleta")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.4 — Sua pergunta
#
# Formule uma pergunta própria sobre a sua coleta (por exemplo: "vídeos com música original têm mais engajamento que os com áudio de terceiros?", "há relação entre número de hashtags usadas e visualizações?") e responda com código, reaproveitando o que fez até aqui.
#
# **Pergunta escolhida:**
#
# vídeos com a hashtag #tutorial tem mais engajamento?
#
# **Resposta (com o código usado):**

# %%
# escreva aqui o código da sua pergunta

import pandas as pd
df = pd.read_csv("dados/exportacao.csv", sep=";")

df["tem_tutorial"] = df["hashtags"].str.contains("tutorial", case=False, na=False)

df["engajamento"] = (
    df["likes"] + df["comments"] + df["shares"]
) / df["plays"]

df["taxa_engajamento"] = (
    df["engajamento"] / df["plays"]
) * 100

resultado = df.groupby("tem_tutorial")["taxa_engajamento"].mean()

print(resultado)
# Out:
# tem_tutorial
# False    0.000335
# True     0.000022
# Name: taxa_engajamento, dtype: float64

# %% [markdown]
# **Interpretação, em texto:**
#
# > Escreva aqui o que os números/gráfico mostram, e o que eles não permitem concluir.

# %% [markdown]
# ## Parte 6 — Documentando a coleta
#
# Crie `projetos/04-coleta-redes/README.md` (na sua pasta de entregas, não aqui) e responda:
#
# **Fonte (plataforma e recorte coletado):**
#
# > Escreva aqui.
#
# **Período da coleta (data e hora de início e fim):**
#
# > Escreva aqui.
#
# **Consulta/coleta realizada (o que exatamente foi navegado: hashtag, perfil, busca):**
#
# > Escreva aqui.
#
# **Campos disponíveis no arquivo exportado (cole a lista impressa na Parte 2):**
#
# > Escreva aqui.
#
# **Limites éticos do conjunto (o que esse conjunto NÃO permite concluir, e quais cuidados foram tomados na coleta):**
#
# > Escreva aqui.

# %% [markdown]
# ## Parte 7 — Conferência final
#
# Antes de considerar a entrega concluída, confira:
#
# - [ ] O arquivo `exportacao.csv`, as thumbnails e os vídeos estão em `projetos/04-coleta-redes/exercicios/dados/` (ou pasta equivalente da sua entrega), e essa pasta está no `.gitignore`.
# - [ ] A Parte 2 rodou sem erro e mostrou o número de itens e os campos disponíveis, com cinco colunas descritas.
# - [ ] As duas nuvens de palavras (texto e hashtags) foram geradas.
# - [ ] Os downloads de thumbnails e vídeos rodaram sem erro (ou os erros foram entendidos e ignorados, seção 15 da aula).
# - [ ] A Parte 5 está completa: estatísticas das quatro métricas, taxa de engajamento, gráfico de curtidas por autor e sua pergunta própria respondida e interpretada.
# - [ ] `projetos/04-coleta-redes/README.md` responde às quatro perguntas da Parte 6.
# - [ ] O recorte coletado é público e está dentro do combinado em aula.
# - [ ] Esse notebook está copiado dentro de `projetos/04-coleta-redes/` na sua pasta de entregas.
# - [ ] Você já fez `git add`, `git commit` e `git push` dessa entrega (Aula 3, se precisar relembrar os comandos).
